# %% [markdown]
# - [ワークスペース オブジェクトの識別子を取得する](https://docs.databricks.com/aws/ja/workspace/workspace-details)
# - [シークレット管理](https://docs.databricks.com/aws/ja/security/secrets/)
# - [Genieスペース ID](https://docs.databricks.com/aws/ja/genie/conversation-api#%E3%82%B9%E3%83%86%E3%83%83%E3%83%97-1-genie%E3%82%B9%E3%83%9A%E3%83%BC%E3%82%B9%E3%82%92%E4%BD%9C%E6%88%90%E3%81%97%E3%81%A6%E3%83%86%E3%82%B9%E3%83%88%E3%81%99%E3%82%8B:~:text=Genie%E3%82%B9%E3%83%9A%E3%83%BC%E3%82%B9%20URL%20%E3%82%92%E4%BD%BF%E7%94%A8%E3%81%97%E3%81%A6%E3%80%81%E3%83%AF%E3%83%BC%E3%82%AF%E3%82%B9%E3%83%9A%E3%83%BC%E3%82%B9%20%E3%82%A4%E3%83%B3%E3%82%B9%E3%82%BF%E3%83%B3%E3%82%B9%E5%90%8D%E3%81%A8Genie%E3%82%B9%E3%83%9A%E3%83%BC%E3%82%B9%20ID%20%E3%82%92%E8%A6%8B%E3%81%A4%E3%81%91%E3%81%BE%E3%81%99)

# %%
# ワークスペース / Genie Space 設定 （ご自身の環境に合わせて書き換えてください）
WORKSPACE_URL = "https://<your-workspace-url>"          # 例: https://adb-xxxxxxxxx.azuredatabricks.net
GENIE_SPACE_ID = "<your-genie-space-id>"                # Genie Space の ID（Genie スペースを作成したら入力してください）
# WORKSPACE_URL = "https://adb-984752964297111.11.azuredatabricks.net"    # 例: https://adb-xxxxxxxxx.azuredatabricks.net
# GENIE_SPACE_ID = "01f0d3310f93181fb3715f805a602c66"                     # Genie Space の ID（Genie スペースを作成したら更新してください）

# 認証トークン（Databricks PAT を Secrets から取得する想定）
DATABRICKS_TOKEN = "<your-parsonal-access-token>"  # パーソナルアクセストークンを入力してください
# DATABRICKS_TOKEN = dbutils.secrets.get("komae_scope", "genie_api")  # スコープ名/キー名は環境に合わせて変更

# Genie API ベースURL
GENIE_API_BASE = f"{WORKSPACE_URL}/api/2.0/genie/spaces/{GENIE_SPACE_ID}"

# %%
# 設定内容を表示
print("=== Genie Config ===")
print(f"WORKSPACE_URL : {WORKSPACE_URL}")
print(f"GENIE_SPACE_ID: {GENIE_SPACE_ID}")
print(f"GENIE_API_BASE: {GENIE_API_BASE}")
print(f"DATABRICKS_TOKEN: {DATABRICKS_TOKEN}")
